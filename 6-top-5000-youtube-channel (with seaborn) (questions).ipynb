# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv('6-top-5000-youtube-channels.csv')
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# # 1. Display all rows except the last 5 rows using head method

# %%
data.head((data.shape[0])-5)

# %%
#data.head(-5)

# %% [markdown]
# # 2. Display all rows except the first 5 rows using tail method

# %%
data.tail((data.shape[0])-5)
#data.tail(-5)

# %% [markdown]
# # 3. Find Shape of our dataset (Number of rows & number of columns)

# %%
data.shape

# %% [markdown]
# # 4. Get Information about our dataset like total number of rows, columns, datatypes & memory requirement

# %%
data.shape[0]

# %%
data.shape[1]

# %%
data.dtypes

# %% [markdown]
# # 5. Get overall statistics about our dataframe

# %%
data.describe()

# %% [markdown]
# # 6. Data Cleaning (Replace'--' to NaN)

# %%
data.replace('--', np.nan)

# %% [markdown]
# # 7. Check null values in the dataset

# %%
data.isnull()

# %%
data.isnull().sum()*100/len(data)

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull()) #as you can see that there are no missing values in our data set
# Out:
# <Axes: >

# %% [markdown]
# # 8. Data Cleaning [Rank Column]

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
#as we can see that in the rank column, it is written as 1st, 2nd & so on which is a string, so we are going to remove that string

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
#also we can see that there are commas along with  the above string data

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
#as we can see that all the column have data types as object, except the video views, so we are going to convert the rank column to interegre data type

# %%
data['Rank']=data['Rank'].str[0:-2] #here we are using slicing to modify our exiting dataframe

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#        Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998   B+         Mastersaint           110     3265735    311758426
# 4998  4,999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data.tail()
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
#now we need to convert the data type from string to integer

# %%
data['Rank']=data['Rank'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
#as you can see now it is a integer data type, you can use this method to clean any type of data

# %% [markdown]
# # 9. Data Cleaning [Video Uploads & Subscribers]

# %%
data.head()
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0     1  A++                       Zee TV         82757    18752951
# 1     2  A++                     T-Series         12661    61196302
# 2     3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3     4  A++                    SET India         27323    31180559
# 4     5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
#as you can see that both the columns, video uploads & subscribers gave object datatype, but the data is into numerical format, so we just need to conevrt the datatype of that column

# %%
data['Video Uploads']=data['Video Uploads'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Subscribers']=data['Subscribers'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %%
#as you can see that both the columns are now of integer datatype

# %% [markdown]
# # 10. Data Cleaning [Grade Column]

# %%
data.head()
# Out:
#    Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0     1  A++                       Zee TV          82757     18752951
# 1     2  A++                     T-Series          12661     61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3     4  A++                    SET India          27323     31180559
# 4     5  A++                          WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#       Rank Grade       Channel name  Video Uploads  Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu            706      2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD            797      1055091    377331722
# 4997  4998   B+         Mastersaint            110      3265735    311758426
# 4998  4999   B+      Bruce McIntosh           3475        32990     14563764
# 4999  5000   B+           SehatAQUA            254        21172     73312511

# %%
data['Grade'].unique() # as you can see that this are the values avialble in Grade column
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']=data['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1,}) #we are using pandas map method & passing the values as dictonary in the map method
#it means 'A++':5, grade of A++ is grade 5 & so on...

# %%
data['Grade'] = data['Grade'].str.strip().map({'A++': 5, 'A+': 4, 'A': 3, 'A-': 2, 'B+': 1})
data.groupby('Grade').mean(numeric_only=True)

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.dtypes
# Out:
# Rank              int32
# Grade             int64
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %%
#as you can see that the data type has been changed

# %% [markdown]
# # 11. Find average views for each channel

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.groupby('Channel name')['Video views'].mean()

# %%
#data['avg_views']=data['Video views']/data['Video Uploads']

# %% [markdown]
# # 12. Find out top 5 channels with maximum number of video upload

# %%
data.groupby('Channel name')['Video Uploads'].mean().sort_values(ascending=False).head()

# %%
#data.sort_values(by='Video Uploads',ascending=False).head()

# %% [markdown]
# # 13. Find correlation matrix

# %%
data[['Video Uploads','Subscribers','Video views']].corr()

# %%
data.corr(numeric_only=True)

# %% [markdown]
# # 14. Which Grade has a maxium number of video uploads ?

# %%
data.groupby('Grade')['Video Uploads'].max().sort_values(ascending=False).head(1)

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)

# %% [markdown]
# # 15. Which Grade has the highest average views ?

# %%
data.groupby('Grade')['Video views'].mean().sort_values(ascending=False).head(1)

# %%
sns.barplot(x='Grade',y='avg_views',data=data)

# %% [markdown]
# # 16. Which Grade has the highest number of subscribers ?

# %%
data.groupby('Grade')['Subscribers'].max().sort_values(ascending=False).head(1)

# %%
sns.barplot(x='Grade',y='Subscribers',data=data)

# %% [markdown]
# # 17. Which Grade has the highest video views

# %%
data.groupby('Grade')['Video views'].max().sort_values(ascending=False).head(1)

# %%
#data.groupby('Grade').mean()

# %%
data['Grade'] = data['Grade'].str.strip().map({'A++': 5, 'A+': 4, 'A': 3, 'A-': 2, 'B+': 1})
data.groupby('Grade').mean(numeric_only=True)

# %%
# Step 1 - Fix Subscribers dtype
data.columns = data.columns.str.strip()
data['Subscribers'] = pd.to_numeric(data['Subscribers'].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# Step 2 - Check it worked
print(data['Subscribers'].dtype)        # should show float64 or int64
print(data['Subscribers'].head())

# Step 3 - Now groupby and sort
data.groupby('Grade').mean(numeric_only=True).sort_values(by='Subscribers', ascending=False)
